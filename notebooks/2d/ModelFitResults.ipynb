# %%
import arviz as az
# Out:
# /scratch/ds2181/cpp-proprioception/.venv/lib/python3.10/site-packages/arviz/__init__.py:50: FutureWarning:
# ArviZ is undergoing a major refactor to improve flexibility and extensibility while maintaining a user-friendly interface.
# Some upcoming changes may be backward incompatible.
# For details and migration guidance, visit: https://python.arviz.org/en/latest/user_guide/migration_guide.html
#   warn(

# %%
idata = az.from_netcdf("../../results/2d/mcmc-[12, 22]-CorrelatedObservationModel-1.nc")

# %%
az.plot_trace(idata)
# Out:
# /scratch/ds2181/cpp-proprioception/.venv/lib/python3.10/site-packages/arviz/stats/density_utils.py:488: UserWarning: Your data appears to have a single value or no finite values
#   warnings.warn("Your data appears to have a single value or no finite values")
# array([[<Axes: title={'center': 'L'}>, <Axes: title={'center': 'L'}>],
#        [<Axes: title={'center': 'action_cost'}>,
#         <Axes: title={'center': 'action_cost'}>],
#        [<Axes: title={'center': 'action_variability'}>,
#         <Axes: title={'center': 'action_variability'}>],
#        [<Axes: title={'center': 'rho'}>, <Axes: title={'center': 'rho'}>],
#        [<Axes: title={'center': 'sigma'}>,
#         <Axes: title={'center': 'sigma'}>]], dtype=object)
